# %%
import pandas as pd

# %%
# Load data
temp_change_df = pd.read_csv("../Resources/Annual_Surface_Temperature_Change.csv")

# %%
temp_change_df.head()
# Out:
#    ObjectId                       Country ISO2 ISO3  \
# 0         1  Afghanistan, Islamic Rep. of   AF  AFG
# 1         2                       Albania   AL  ALB
# 2         3                       Algeria   DZ  DZA
# 3         4                American Samoa   AS  ASM
# 4         5      Andorra, Principality of   AD  AND
#
#                                            Indicator            Unit  \
# 0  Temperature change with respect to a baseline ...  Degree Celsius
# 1  Temperature change with respect to a baseline ...  Degree Celsius
# 2  Temperature change with respect to a baseline ...  Degree Celsius
# 3  Temperature change with respect to a baseline ...  Degree Celsius
# 4  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                               Source CTS_Code  \
# 0  Food and Agriculture Organization of the Unite...     ECCS
# 1  Food and Agriculture Organization of the Unite...     ECCS
# ...

# %%
temp_change_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 71 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ObjectId             227 non-null    int64
#  1   Country              227 non-null    object
#  2   ISO2                 225 non-null    object
#  3   ISO3                 227 non-null    object
#  4   Indicator            227 non-null    object
#  5   Unit                 227 non-null    object
#  6   Source               227 non-null    object
#  7   CTS_Code             227 non-null    object
#  8   CTS_Name             227 non-null    object
#  9   CTS_Full_Descriptor  227 non-null    object
#  10  F1961                191 non-null    float64
#  11  F1962                192 non-null    float64
#  12  F1963                191 non-null    float64
#  13  F1964                190 non-null    float64
#  14  F1965                190 non-null    float64
# ...

# %%
# Let's take a look at what values are in some of these columns
for col in ['Indicator', 'Unit', 'Source', 'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor']:
    print(temp_change_df[col].value_counts())
    print("--------------------")
# Out:
# Temperature change with respect to a baseline climatology, corresponding to the period 1951-1980    227
# Name: Indicator, dtype: int64
# --------------------
# Degree Celsius    227
# Name: Unit, dtype: int64
# --------------------
# Food and Agriculture Organization of the United Nations (FAO). 2022. FAOSTAT Climate Change, Climate Indicators, Temperature change. License: CC BY-NC-SA 3.0 IGO. Extracted from: https://www.fao.org/faostat/en/#data/ET. Accessed on 2022-05-03.    227
# Name: Source, dtype: int64
# --------------------
# ECCS    227
# Name: CTS_Code, dtype: int64
# --------------------
# Surface Temperature Change    227
# Name: CTS_Name, dtype: int64
# --------------------
# Environment, Climate Change, Climate Indicators, Surface Temperature Change    227
# Name: CTS_Full_Descriptor, dtype: int64
# --------------------

# %%
# Since these columns all have the same values, we can pull them out as a data series
temp_change_metadata = temp_change_df[['Indicator', 'Unit', 'Source', 'CTS_Code', 
                                       'CTS_Name', 'CTS_Full_Descriptor']].iloc[0]
temp_change_metadata
# Out:
# Indicator              Temperature change with respect to a baseline ...
# Unit                                                      Degree Celsius
# Source                 Food and Agriculture Organization of the Unite...
# CTS_Code                                                            ECCS
# CTS_Name                                      Surface Temperature Change
# CTS_Full_Descriptor    Environment, Climate Change, Climate Indicator...
# Name: 0, dtype: object

# %%
# Now we can get rid of these rows as well as the ISO2 and ObjectID
temp_change_years = temp_change_df.drop(columns=['ObjectId', 'ISO2', 'Indicator', 'Unit', 'Source', 
                                         'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor'])
temp_change_years.head()
# Out:
#                         Country ISO3  F1961  F1962  F1963  F1964  F1965  \
# 0  Afghanistan, Islamic Rep. of  AFG -0.105 -0.157  0.852 -0.743 -0.211
# 1                       Albania  ALB  0.627  0.330  0.068 -0.172 -0.393
# 2                       Algeria  DZA  0.162  0.131  0.110  0.284 -0.081
# 3                American Samoa  ASM  0.066 -0.055  0.160 -0.150 -0.582
# 4      Andorra, Principality of  AND  0.744  0.102 -0.762  0.300 -0.492
#
#    F1966  F1967  F1968  ...  F2012  F2013  F2014  F2015  F2016  F2017  F2018  \
# 0  0.156 -0.389 -0.384  ...  0.234  1.308  0.457  1.101  1.607  1.568  1.580
# 1  0.553 -0.080  0.073  ...  1.568  1.444  1.322  1.665  1.601  1.269  2.146
# 2  0.436  0.006 -0.027  ...  1.128  1.173  1.676  1.101  1.736  1.498  1.211
# 3  0.166 -0.364 -0.174  ...  0.646  0.883  0.554  0.394  0.924  0.820  0.574
# 4  0.407  0.621 -0.013  ...  1.196  0.757  1.857  1.546  1.830  1.771  1.761
#
#    F2019  F2020  F2021
# 0  0.960  0.544  1.421
# ...

# %%
# Rename the year columns to be just the number
for col in range(2, len(temp_change_years.columns)):
    temp_change_years.rename(columns={temp_change_years.columns[col]:temp_change_years.columns[col][1:]}, inplace=True)

# %%
temp_change_years.columns
# Out:
# Index(['Country', 'ISO3', '1961', '1962', '1963', '1964', '1965', '1966',
#        '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021'],
#       dtype='object')

# %%
# Transfer the year columns to rows
temp_change = temp_change_years.melt(id_vars=['Country', 'ISO3'], var_name='Year', value_name='Temp_Change')

# %%
temp_change.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13847 entries, 0 to 13846
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      13847 non-null  object
#  1   ISO3         13847 non-null  object
#  2   Year         13847 non-null  object
#  3   Temp_Change  12333 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 432.8+ KB

# %%
# Change year to int datatype 
temp_change['Year'] = temp_change['Year'].astype('int')

# %%
temp_change.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13847 entries, 0 to 13846
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      13847 non-null  object
#  1   ISO3         13847 non-null  object
#  2   Year         13847 non-null  int32
#  3   Temp_Change  12333 non-null  float64
# dtypes: float64(1), int32(1), object(2)
# memory usage: 378.8+ KB

# %%
temp_change
# Out:
#                             Country ISO3  Year  Temp_Change
# 0      Afghanistan, Islamic Rep. of  AFG  1961       -0.105
# 1                           Albania  ALB  1961        0.627
# 2                           Algeria  DZA  1961        0.162
# 3                    American Samoa  ASM  1961        0.066
# 4          Andorra, Principality of  AND  1961        0.744
# ...                             ...  ...   ...          ...
# 13842                Western Sahara  ESH  2021        1.557
# 13843                         World  WLD  2021        1.442
# 13844                Yemen, Rep. of  YEM  2021          NaN
# 13845                        Zambia  ZMB  2021        1.002
# 13846                      Zimbabwe  ZWE  2021       -0.101
#
# [13847 rows x 4 columns]

# %%
# Export data and metadata
temp_change.to_csv("../Resources/Temperature_Change.csv")
temp_change_metadata.to_csv("../Resources/Temperature_Change_Metadata.csv")
