# %%
# Dependencies:
import pandas as pd

# %%
# Load CSV and sample:
emission_df = pd.read_csv("../Resources/GCB2022v27_MtCO2_flat.csv")
# emission_df[(emission_df['Year'].values >= 1965) & (emission_df['Country'].values == 'USA')]
emission_df
# Out:
#            Country ISO 3166-1 alpha-3  Year         Total          Coal  \
# 0      Afghanistan                AFG  1750      0.000000           NaN
# 1      Afghanistan                AFG  1751      0.000000           NaN
# 2      Afghanistan                AFG  1752      0.000000           NaN
# 3      Afghanistan                AFG  1753      0.000000           NaN
# 4      Afghanistan                AFG  1754      0.000000           NaN
# ...            ...                ...   ...           ...           ...
# 63099       Global                WLD  2017  36096.739276  14506.973805
# 63100       Global                WLD  2018  36826.506600  14746.830688
# 63101       Global                WLD  2019  37082.558969  14725.978025
# 63102       Global                WLD  2020  35264.085734  14174.564010
# 63103       Global                WLD  2021  37123.850352  14979.598083
#
#                 Oil          Gas       Cement     Flaring       Other  \
# ...

# %%
# Check null and drop any null values:
emission_df.isnull().sum()
# Out:
# Country                   0
# ISO 3166-1 alpha-3     1632
# Year                      0
# Total                   200
# Coal                  41360
# Oil                   41387
# Gas                   41486
# Cement                42290
# Flaring               41554
# Other                 61484
# Per Capita            44130
# dtype: int64

# %%
emission_df = emission_df.dropna(how='any')
emission_df
# Out:
#          Country ISO 3166-1 alpha-3  Year         Total          Coal  \
# 3232   Australia                AUS  1990    278.154156    141.879819
# 3233   Australia                AUS  1991    279.528510    146.082840
# 3234   Australia                AUS  1992    284.525345    150.051381
# 3235   Australia                AUS  1993    288.870537    150.098575
# 3236   Australia                AUS  1994    293.696553    151.376241
# ...          ...                ...   ...           ...           ...
# 63099     Global                WLD  2017  36096.739276  14506.973805
# 63100     Global                WLD  2018  36826.506600  14746.830688
# 63101     Global                WLD  2019  37082.558969  14725.978025
# 63102     Global                WLD  2020  35264.085734  14174.564010
# 63103     Global                WLD  2021  37123.850352  14979.598083
#
#                 Oil          Gas       Cement     Flaring       Other  \
# ...

# %%
# Rename column ISO 3166-1 alpha-3 to Country Code:
emission_df = emission_df.rename(columns={'ISO 3166-1 alpha-3':'Country Code', 'Per Capita': 'PerCapita'})
emission_df.sample(25)
# Out:
#               Country Country Code  Year        Total         Coal  \
# 60089             USA          USA  1999  5810.331395  2065.357732
# 32610      Luxembourg          LUX  1992    12.209723     5.539509
# 26359         Ireland          IRL  1997    38.804985    12.210017
# 55474          Taiwan          TWN  2008   266.595000   155.266155
# 55483          Taiwan          TWN  2017   284.821000   162.617632
# 19282          France          FRA  1992   406.648330    77.786511
# 18746         Finland          FIN  2000    57.009923    21.985056
# 60069             USA          USA  1979  5008.578779  1427.458000
# 18757         Finland          FIN  2011    56.637171    24.079079
# 47037         Romania          ROU  2003   102.844232    34.889629
# 8427         Bulgaria          BGR  2017    47.569757    25.793896
# 3516          Austria          AUT  2002    71.953612    16.736632
# 47304          Russia          RUS  1998  1464.542998   400.158472
# ...

# %%
emission_df.to_csv('emission_cleaned.csv')

# %%
# Load CSV and drop columns not needed:
world_pop_df = pd.read_csv("../Resources/world_pop.csv")
world_pop_df = world_pop_df.drop(columns=["Indicator Code","Indicator Name"])
world_pop_df
# Out:
#                     Country Name Country Code       1960       1961  \
# 0                          Aruba          ABW      54608      55811
# 1    Africa Eastern and Southern          AFE  130692579  134169237
# 2                    Afghanistan          AFG    8622466    8790140
# 3     Africa Western and Central          AFW   97256290   99314028
# 4                         Angola          AGO    5357195    5441333
# ..                           ...          ...        ...        ...
# 259                       Kosovo          XKX     947000     966000
# 260                  Yemen, Rep.          YEM    5542459    5646668
# 261                 South Africa          ZAF   16520441   16989464
# 262                       Zambia          ZMB    3119430    3219451
# 263                     Zimbabwe          ZWE    3806310    3925952
#
#           1962       1963       1964       1965       1966       1967  ...  \
# ...

# %%
# Stacked
world_pop_df3 = pd.DataFrame(world_pop_df.set_index(['Country Name', 
                                                     'Country Code']).stack())
world_pop_df3.sample(100)
# Out:
#                                                     0
# Country Name             Country Code
# St. Martin (French part) MAF          1995      29435
# Angola                   AGO          1984    9617702
# Mali                     MLI          2009   15032635
# Romania                  ROU          2019   19371648
# South Asia (IDA & IBRD)  TSA          1963  613229525
# ...                                               ...
# Germany                  DEU          2016   82348669
# Monaco                   MCO          1993      31024
# Maldives                 MDV          2003     297226
# Madagascar               MDG          2013   23588073
# Slovenia                 SVN          1973    1766697
#
# [100 rows x 1 columns]

# %%
world_pop_df3.to_csv('world_population_by_year.csv')
