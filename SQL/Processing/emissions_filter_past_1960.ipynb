# %%
import pandas as pd

# %%
#creating the dataframe
spreadsheet1 = pd.read_csv('Resources/GCB2022v27_MtCO2_flat.csv')
spreadsheet1
# Out:
#            Country ISO 3166-1 alpha-3  Year         Total          Coal  \
# 0      Afghanistan                AFG  1750      0.000000           NaN
# 1      Afghanistan                AFG  1751      0.000000           NaN
# 2      Afghanistan                AFG  1752      0.000000           NaN
# 3      Afghanistan                AFG  1753      0.000000           NaN
# 4      Afghanistan                AFG  1754      0.000000           NaN
# ...            ...                ...   ...           ...           ...
# 63099       Global                WLD  2017  36096.739276  14506.973805
# 63100       Global                WLD  2018  36826.506600  14746.830688
# 63101       Global                WLD  2019  37082.558969  14725.978025
# 63102       Global                WLD  2020  35264.085734  14174.564010
# 63103       Global                WLD  2021  37123.850352  14979.598083
#
#                 Oil          Gas       Cement     Flaring       Other  \
# ...

# %%
#renaming columns to match postgres column names
spreadsheet1.columns = ["country", "country_code", "year", "total", "coal", "oil", "gas", "cement", "flaring", "other", "per_capita"]
spreadsheet1
# Out:
#            country country_code  year         total          coal  \
# 0      Afghanistan          AFG  1750      0.000000           NaN
# 1      Afghanistan          AFG  1751      0.000000           NaN
# 2      Afghanistan          AFG  1752      0.000000           NaN
# 3      Afghanistan          AFG  1753      0.000000           NaN
# 4      Afghanistan          AFG  1754      0.000000           NaN
# ...            ...          ...   ...           ...           ...
# 63099       Global          WLD  2017  36096.739276  14506.973805
# 63100       Global          WLD  2018  36826.506600  14746.830688
# 63101       Global          WLD  2019  37082.558969  14725.978025
# 63102       Global          WLD  2020  35264.085734  14174.564010
# 63103       Global          WLD  2021  37123.850352  14979.598083
#
#                 oil          gas       cement     flaring       other  \
# 0               NaN          NaN          NaN         NaN         NaN
# ...

# %%
#filtering for dates from 1961
spreadsheet2 = spreadsheet1.loc[(spreadsheet1['year'] >=1961)]
spreadsheet2
# Out:
#            country country_code  year         total          coal  \
# 211    Afghanistan          AFG  1961      0.490798      0.175872
# 212    Afghanistan          AFG  1962      0.688594      0.296784
# 213    Afghanistan          AFG  1963      0.706736      0.263808
# 214    Afghanistan          AFG  1964      0.838551      0.300448
# 215    Afghanistan          AFG  1965      1.006917      0.381056
# ...            ...          ...   ...           ...           ...
# 63099       Global          WLD  2017  36096.739276  14506.973805
# 63100       Global          WLD  2018  36826.506600  14746.830688
# 63101       Global          WLD  2019  37082.558969  14725.978025
# 63102       Global          WLD  2020  35264.085734  14174.564010
# 63103       Global          WLD  2021  37123.850352  14979.598083
#
#                 oil          gas       cement     flaring       other  \
# 211        0.293120     0.000000     0.021806    0.000000         NaN
# ...

# %%
#filtering by country
spreadsheet3 = spreadsheet2[spreadsheet2['country_code'].isin(['AUS', 'AUT', 'BLR', 'BEL', 'BRA', 'BGR', 'CAN', 'CHN', 'HRV', 
    'CYP', 'CZE', 'DNK', 'EST', 'FIN', 'FRA', 'DEU', 'GRC', 'HUN','ISL', 'IRL', 'ITA', 'JPN', 'KAZ', 'LVA', 'LIE', 'LTU', 'LUX',
       'MLT', 'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'KOR', 'ROU', 'RUS',
       'SVK', 'SVN', 'ESP', 'SWE', 'CHE', 'TUR', 'UKR', 'GBR',
       'USA', 'WLD'])]
spreadsheet3
# Out:
#          country country_code  year         total          coal           oil  \
# 3203   Australia          AUS  1961     90.503896     59.974780     29.115323
# 3204   Australia          AUS  1962     94.823455     61.485584     31.884128
# 3205   Australia          AUS  1963    100.934264     63.727952     35.658048
# 3206   Australia          AUS  1964    108.875767     67.133213     39.943584
# 3207   Australia          AUS  1965    120.852669     71.059616     47.906800
# ...          ...          ...   ...           ...           ...           ...
# 63099     Global          WLD  2017  36096.739276  14506.973805  12242.627935
# 63100     Global          WLD  2018  36826.506600  14746.830688  12266.016285
# 63101     Global          WLD  2019  37082.558969  14725.978025  12345.653374
# 63102     Global          WLD  2020  35264.085734  14174.564010  11191.808551
# 63103     Global          WLD  2021  37123.850352  14979.598083  11837.159116
#
# ...

# %%
spreadsheet3.to_csv('resources/emissions_since1961.csv', index=False)
